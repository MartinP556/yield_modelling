# %%
import pyreadr

# %%
result = pyreadr.read_r('C:\\Users\\wlwc1989\\Documents\\yield_modelling\\data\\daily_2005_his_irr.rds')

# Extract the DataFrame
df = result[None]

# Display the first few rows of the DataFrame
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 4
#       1 result = pyreadr.read_r('C:\\Users\\wlwc1989\\Documents\\yield_modelling\\data\\daily_2005_his_irr.rds')
#       3 # Extract the DataFrame
# ----> 4 df = result[None]
#       6 # Display the first few rows of the DataFrame
#       7 print(df.head())
#
# KeyError: None

# %%
df = result['daily_simulated_growth_data']

# %%
df.columns.to_list()
# Out:
# ['run_id',
#  'country',
#  'station',
#  'station_id',
#  'lon',
#  'lat',
#  'soil',
#  'cycle',
#  'crop',
#  'time_horizon',
#  'SSP',
#  'GCM',
#  'Irrigation_status',
#  'date',
#  'DVS',
#  'LAI',
#  'TAGP',
#  'TWSO',
#  'TWLV',
#  'TWST',
#  'TWRT',
#  'TRA',
#  'EVS',
#  'ET',
#  'RD',
#  'RFWS']
